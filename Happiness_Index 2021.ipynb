# %%
#Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Inserting the data set

df_original=pd.read_excel('world-happiness-report-2021_xls.xls')

# %%
df_original.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %%
# from sklearn.preprocessing import minmax_scale
# import pandas as pd

# df_original = minmax_scale(df_original[['Explained by: Log GDP per capita','Explained by: Social support']], feature_range=(0,1))

# df_original['Explained by: Log GDP per capita']=df_original[:,0]
# df_original['Explained by: Social support']=df_original[:,1]

# %%
df_original.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
df=df_original[['Country name','Explained by: Log GDP per capita','Explained by: Healthy life expectancy','Explained by: Generosity','Explained by: Social support','Ladder score','Learning Rate Updated','Human Development Index Updated']]

# %%
df.head()
# Out:
#   Country name  Explained by: Log GDP per capita  \
# 0      Finland                             1.446
# 1      Denmark                             1.502
# 2  Switzerland                             1.566
# 3      Iceland                             1.482
# 4  Netherlands                             1.501
#
#    Explained by: Healthy life expectancy  Explained by: Generosity  \
# 0                                  0.741                     0.124
# 1                                  0.763                     0.208
# 2                                  0.816                     0.204
# 3                                  0.772                     0.293
# 4                                  0.753                     0.302
#
#    Explained by: Social support  Ladder score  Learning Rate Updated  \
# 0                         1.106         7.842               0.428571
# 1                         1.108         7.620               0.423280
# ...

# %%
df.describe()
# Out:
#        Explained by: Log GDP per capita  \
# count                        149.000000
# mean                           0.977161
# std                            0.404740
# min                            0.000000
# 25%                            0.666000
# 50%                            1.025000
# 75%                            1.323000
# max                            1.751000
#
#        Explained by: Healthy life expectancy  Explained by: Generosity  \
# count                             149.000000                149.000000
# mean                                0.520161                  0.178047
# std                                 0.213019                  0.098270
# min                                 0.000000                  0.000000
# 25%                                 0.357000                  0.105000
# 50%                                 0.571000                  0.164000
# 75%                                 0.665000                  0.239000
# ...

# %%
# sns.pairplot(df_original)

# %%
# sns.pairplot(df)

# %%
# sns.pairplot(df_original)

# %%
sns.pairplot(df,hue='Ladder score')

# %%
df.describe()
# Out:
#        Explained by: Log GDP per capita  \
# count                        149.000000
# mean                           0.977161
# std                            0.404740
# min                            0.000000
# 25%                            0.666000
# 50%                            1.025000
# 75%                            1.323000
# max                            1.751000
#
#        Explained by: Healthy life expectancy  Explained by: Generosity  \
# count                             149.000000                149.000000
# mean                                0.520161                  0.178047
# std                                 0.213019                  0.098270
# min                                 0.000000                  0.000000
# 25%                                 0.357000                  0.105000
# 50%                                 0.571000                  0.164000
# 75%                                 0.665000                  0.239000
# ...

# %%
df_gdp=df['Explained by: Log GDP per capita'].head()

# %%
sns.displot(x='Ladder score',data=df,kind='kde')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country name                           149 non-null    object
#  1   Explained by: Log GDP per capita       149 non-null    float64
#  2   Explained by: Healthy life expectancy  149 non-null    float64
#  3   Explained by: Generosity               149 non-null    float64
#  4   Explained by: Social support           149 non-null    float64
#  5   Ladder score                           149 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 7.1+ KB

# %%
# df['Country name']=df['Country name'].astype(float)

# %%
df['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
# sns.heatmap(data=df)

# %%
df_own=pd.read_excel('final_data.xlsx')

# %%
df_own.describe()
# Out:
#        Primary key         HI        GDP         LE        SPS  Generosity
# count    99.000000  99.000000  99.000000  99.000000  99.000000   99.000000
# mean     49.000000   0.563274   0.183181   0.654709   0.568933    0.400142
# std      28.722813   0.212048   0.228875   0.220951   0.281447    0.143267
# min       0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 25%      24.500000   0.392910   0.029481   0.523364   0.390440    0.315789
# 50%      49.000000   0.582712   0.070659   0.663551   0.571588    0.385965
# 75%      73.500000   0.702789   0.263771   0.834891   0.822872    0.491228
# max      98.000000   1.000000   1.000000   1.000000   1.000000    1.000000

# %%
df.describe()
# Out:
#        Explained by: Log GDP per capita  \
# count                        149.000000
# mean                           0.977161
# std                            0.404740
# min                            0.000000
# 25%                            0.666000
# 50%                            1.025000
# 75%                            1.323000
# max                            1.751000
#
#        Explained by: Healthy life expectancy  Explained by: Generosity  \
# count                             149.000000                149.000000
# mean                                0.520161                  0.178047
# std                                 0.213019                  0.098270
# min                                 0.000000                  0.000000
# 25%                                 0.357000                  0.105000
# 50%                                 0.571000                  0.164000
# 75%                                 0.665000                  0.239000
# ...

# %%
sns.pairplot(df_own,hue='HI')

# %%
sns.pairplot(df_own)

# %%
df_own.head()
# Out:
#    Primary key    Country        HI       GDP        LE       SPS  Generosity
# 0            0    Albania  0.419842  0.055552  0.741433  0.595265    0.368421
# 1            1    Algeria  0.370875  0.028669  0.738318  0.428412    0.333333
# 2            2  Argentina  0.592719  0.099079  0.707165  0.726379    0.350877
# 3            3  Australia  0.859698  0.659038  0.990654  0.947509    0.649123
# 4            4    Austria  0.877794  0.528649  0.900312  0.928747    0.385965

# %%
df_own.describe()
# Out:
#        Primary key         HI        GDP         LE        SPS  Generosity
# count    99.000000  99.000000  99.000000  99.000000  99.000000   99.000000
# mean     49.000000   0.563274   0.183181   0.654709   0.568933    0.400142
# std      28.722813   0.212048   0.228875   0.220951   0.281447    0.143267
# min       0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 25%      24.500000   0.392910   0.029481   0.523364   0.390440    0.315789
# 50%      49.000000   0.582712   0.070659   0.663551   0.571588    0.385965
# 75%      73.500000   0.702789   0.263771   0.834891   0.822872    0.491228
# max      98.000000   1.000000   1.000000   1.000000   1.000000    1.000000

# %%
df.describe()
# Out:
#        Explained by: Log GDP per capita  \
# count                        149.000000
# mean                           0.977161
# std                            0.404740
# min                            0.000000
# 25%                            0.666000
# 50%                            1.025000
# 75%                            1.323000
# max                            1.751000
#
#        Explained by: Healthy life expectancy  Explained by: Generosity  \
# count                             149.000000                149.000000
# mean                                0.520161                  0.178047
# std                                 0.213019                  0.098270
# min                                 0.000000                  0.000000
# 25%                                 0.357000                  0.105000
# 50%                                 0.571000                  0.164000
# 75%                                 0.665000                  0.239000
# ...

# %%
df.dtypes
# Out:
# Country name                              object
# Explained by: Log GDP per capita         float64
# Explained by: Healthy life expectancy    float64
# Explained by: Generosity                 float64
# Explained by: Social support             float64
# Ladder score                             float64
# dtype: object

# %%
sns.displot(x='Explained by: Log GDP per capita',data=df, kind='kde')

# %%
df
# Out:
#     Country name  Explained by: Log GDP per capita  \
# 0        Finland                             1.446
# 1        Denmark                             1.502
# 2    Switzerland                             1.566
# 3        Iceland                             1.482
# 4    Netherlands                             1.501
# ..           ...                               ...
# 144      Lesotho                             0.451
# 145     Botswana                             1.099
# 146       Rwanda                             0.364
# 147     Zimbabwe                             0.457
# 148  Afghanistan                             0.370
#
#      Explained by: Healthy life expectancy  Explained by: Generosity  \
# 0                                    0.741                     0.124
# 1                                    0.763                     0.208
# 2                                    0.816                     0.204
# 3                                    0.772                     0.293
# ...

# %%
df_heat=df[['Explained by: Generosity','Explained by: Log GDP per capita',	'Explained by: Healthy life expectancy',	'Explained by: Social support',	'Ladder score']]

# %%
df[['Explained by: Generosity','Explained by: Log GDP per capita']]
# Out:
#      Explained by: Generosity  Explained by: Log GDP per capita
# 0                       0.124                             1.446
# 1                       0.208                             1.502
# 2                       0.204                             1.566
# 3                       0.293                             1.482
# 4                       0.302                             1.501
# ..                        ...                               ...
# 144                     0.103                             0.451
# 145                     0.027                             1.099
# 146                     0.227                             0.364
# 147                     0.157                             0.457
# 148                     0.122                             0.370
#
# [149 rows x 2 columns]

# %%
sns.heatmap(df_heat.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
df_own
# Out:
#     Primary key     Country        HI       GDP        LE       SPS  \
# 0             0     Albania  0.419842  0.055552  0.741433  0.595265
# 1             1     Algeria  0.370875  0.028669  0.738318  0.428412
# 2             2   Argentina  0.592719  0.099079  0.707165  0.726379
# 3             3   Australia  0.859698  0.659038  0.990654  0.947509
# 4             4     Austria  0.877794  0.528649  0.900312  0.928747
# ..          ...         ...       ...       ...       ...       ...
# 94           94     Uruguay  0.699595  0.164413  0.707165  0.743578
# 95           95  Uzbekistan  0.645944  0.012036  0.566978  0.402948
# 96           96     Vietnam  0.482436  0.029227  0.651090  0.487827
# 97           97      Zambia  0.197573  0.002692  0.264798  0.121287
# 98           98    Zimbabwe  0.000000  0.006811  0.205607  0.122180
#
#     Generosity
# 0     0.368421
# 1     0.333333
# 2     0.350877
# 3     0.649123
# 4     0.385965
# ..         ...
# 94    0.350877
# 95    0.491228
# ...

# %%
# df_own.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_own
# Out:
#     Primary key     Country        HI       GDP        LE       SPS  \
# 0             0     Albania  0.419842  0.055552  0.741433  0.595265
# 1             1     Algeria  0.370875  0.028669  0.738318  0.428412
# 2             2   Argentina  0.592719  0.099079  0.707165  0.726379
# 3             3   Australia  0.859698  0.659038  0.990654  0.947509
# 4             4     Austria  0.877794  0.528649  0.900312  0.928747
# ..          ...         ...       ...       ...       ...       ...
# 94           94     Uruguay  0.699595  0.164413  0.707165  0.743578
# 95           95  Uzbekistan  0.645944  0.012036  0.566978  0.402948
# 96           96     Vietnam  0.482436  0.029227  0.651090  0.487827
# 97           97      Zambia  0.197573  0.002692  0.264798  0.121287
# 98           98    Zimbabwe  0.000000  0.006811  0.205607  0.122180
#
#     Generosity
# 0     0.368421
# 1     0.333333
# 2     0.350877
# 3     0.649123
# 4     0.385965
# ..         ...
# 94    0.350877
# 95    0.491228
# ...

# %%
df_own.describe()
# Out:
#        Primary key         HI        GDP         LE        SPS  Generosity
# count    99.000000  99.000000  99.000000  99.000000  99.000000   99.000000
# mean     49.000000   0.563274   0.183181   0.654709   0.568933    0.400142
# std      28.722813   0.212048   0.228875   0.220951   0.281447    0.143267
# min       0.000000   0.000000   0.000000   0.000000   0.000000    0.000000
# 25%      24.500000   0.392910   0.029481   0.523364   0.390440    0.315789
# 50%      49.000000   0.582712   0.070659   0.663551   0.571588    0.385965
# 75%      73.500000   0.702789   0.263771   0.834891   0.822872    0.491228
# max      98.000000   1.000000   1.000000   1.000000   1.000000    1.000000

# %%
df_own['GDP'].mean()
# Out:
# 0.18318128031541933

# %%
df_own['GDP'].plot()
# Out:
# <Axes: >

# %%
sns.heatmap(df_own.corr(),annot=True,cmap="coolwarm")
# Out:
# <ipython-input-40-443089d5f30c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_own.corr(),annot=True,cmap="coolwarm")
# <Axes: >

# %%
sns.boxplot(df_own[['Generosity','GDP','SPS','LE']])
# Out:
# <Axes: >

# %%
df_own['GDP'].mode()
# Out:
# 0     0.000000
# 1     0.000499
# 2     0.000718
# 3     0.001047
# 4     0.002692
#         ...
# 94    0.670217
# 95    0.681146
# 96    0.881666
# 97    0.924375
# 98    1.000000
# Name: GDP, Length: 99, dtype: float64

# %%
df_own['GDP'].median()
# Out:
# 0.07065932750987196

# %%
df_own.sort_values('GDP')
# Out:
#     Primary key      Country        HI       GDP        LE       SPS  \
# 27           27     Ethiopia  0.240579  0.000000  0.383178  0.020996
# 52           52         Mali  0.335959  0.000499  0.193146  0.000000
# 85           85   Tajikistan  0.494145  0.000718  0.588785  0.189189
# 90           90       Uganda  0.317437  0.001047  0.311526  0.092919
# 97           97       Zambia  0.197573  0.002692  0.264798  0.121287
# ..          ...          ...       ...       ...       ...       ...
# 22           22      Denmark  0.952736  0.670217  0.894081  0.989279
# 36           36      Iceland  0.938684  0.681146  0.934579  0.981014
# 66           66       Norway  0.904194  0.881666  0.950156  1.000000
# 84           84  Switzerland  0.942304  0.924375  0.975078  0.981014
# 40           40      Ireland  0.838833  1.000000  0.912773  0.929417
#
#     Generosity
# 27    0.561404
# 52    0.333333
# 85    0.578947
# 90    0.596491
# 97    0.543860
# ..         ...
# 22    0.438596
# ...
